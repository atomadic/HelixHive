# %% [markdown]
# # SRA v3.2.1.0 - Primary Interface
#
# This notebook serves as the main entry point for the Atomadic Supreme Research Agent.

# %%
import os
import sys

# Ensure local modules are loadable
sys.path.append(os.getcwd())

from activate_agents import activate_agents

activate_agents()

# %%
# Initialize Orchestrator
print("SRA-IDE-Orchestrator ready for input...")
