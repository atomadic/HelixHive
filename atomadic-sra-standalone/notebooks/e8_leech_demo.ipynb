# %% [markdown]
# # E8 / Leech Demo
# Interactive visualization of geometric intelligence.

# %%
import sys
import os
sys.path.append(os.getcwd())
from src.core.e8_core import E8Core
from src.core.leech_outer import LeechOuter

e8 = E8Core()
leech = LeechOuter()

e8.ingest_fact("SRA is active")
trace = leech.explore("Autonomous Evolution")
print(f"Generated Trace: {trace}")
