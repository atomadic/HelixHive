# %% [markdown]
# # RSI Simulation
# Recursive Self-Improvement Protocol simulation.

# %%
import sys
import os
sys.path.append(os.getcwd())
from src.agents.rsi_protocol import RSIProtocol

rsi = RSIProtocol()
status = rsi.propose_modification("Optimize E8 Kernel")
print(f"Proposal Status: {status}")
